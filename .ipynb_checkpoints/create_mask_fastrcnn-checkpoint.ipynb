# %%
# !rm -rf SinGAN_Object_Completion
# !rm *.py
# !rm *.jpg
# !rm -rf vision
# !rm -rf coco*
# Out:
# rm: cannot remove '*.jpg': No such file or directory

# %%
from PIL import Image
import os
import numpy as np
import torch
import torch.utils.data
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone https://github.com/manorzvi/SinGAN_Object_Completion.git
# Out:
# Cloning into 'SinGAN_Object_Completion'...
# remote: Enumerating objects: 352, done.
# remote: Counting objects: 100% (352/352), done.
# remote: Compressing objects: 100% (288/288), done.
# remote: Total 470 (delta 94), reused 310 (delta 54), pack-reused 118
# Receiving objects: 100% (470/470), 200.13 MiB | 33.68 MiB/s, done.
# Resolving deltas: 100% (99/99), done.

# %%
# %%shell
#
# # Install pycocotools
# git clone https://github.com/cocodataset/cocoapi.git
# cd cocoapi/PythonAPI
# python setup.py build_ext install
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 959, done.
# remote: Total 959 (delta 0), reused 0 (delta 0), pack-reused 959
# Receiving objects: 100% (959/959), 11.69 MiB | 11.37 MiB/s, done.
# Resolving deltas: 100% (570/570), done.
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/pycocotools
# ...

# %%
# %%shell
#
# # Download TorchVision repo to use some files from
# # references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.3.0
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 5959 (delta 14), reused 5 (delta 0), pack-reused 5916
# Receiving objects: 100% (5959/5959), 9.57 MiB | 9.08 MiB/s, done.
# Resolving deltas: 100% (3947/3947), done.
# Note: checking out 'v0.3.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at be37608 version check against PyTorch's CUDA version

# %%
from SinGAN_Object_Completion import fastrcnn_mask_functions

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# our dataset has two classes only - background and person
num_classes = 2

# get the model using our helper function
model = fastrcnn_mask_functions.get_instance_segmentation_model(num_classes)
# move model to the right device
model.to(device)
# Out:
# MaskRCNN(
#   (transform): GeneralizedRCNNTransform()
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(original_name=FrozenBatchNorm2d)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(original_name=FrozenBatchNorm2d)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(original_name=FrozenBatchNorm2d)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(original_name=FrozenBatchNorm2d)
#           (relu): ReLU(inplace=True)
# ...

# %%
singan_dir_drive = '/content/gdrive/My Drive/singan/SinGAN'
assert os.path.exists(singan_dir_drive)

models_dir_drive = os.path.join(singan_dir_drive, 'models')
images_dir_drive = os.path.join(singan_dir_drive, 'Input/People')
masks_dir_drive  = os.path.join(singan_dir_drive, 'Input/Masks')
assert os.path.exists(models_dir_drive)
assert os.path.exists(images_dir_drive)
assert os.path.exists(masks_dir_drive)

model_name = 'fastrcnn_segmentation_model_12012019-184816.pth'
model_path_drive = os.path.join(models_dir_drive, model_name)
assert os.path.exists(model_path_drive)

image_name = 'chinese1.jpg'
image_path_drive = os.path.join(images_dir_drive, image_name)
assert os.path.exists(image_path_drive)

# %%
print(model_path_drive)
checkpoint = torch.load(model_path_drive)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
# Out:
# /content/gdrive/My Drive/singan/SinGAN/models/fastrcnn_segmentation_model_12012019-184816.pth
# ---------------------------------------------------------------------------
# EmptyHeaderError                          Traceback (most recent call last)
# /usr/lib/python3.6/tarfile.py in next(self)
#    2296             try:
# -> 2297                 tarinfo = self.tarinfo.fromtarfile(self)
#    2298             except EOFHeaderError as e:
#
# /usr/lib/python3.6/tarfile.py in fromtarfile(cls, tarfile)
#    1092         buf = tarfile.fileobj.read(BLOCKSIZE)
# -> 1093         obj = cls.frombuf(buf, tarfile.encoding, tarfile.errors)
#    1094         obj.offset = tarfile.fileobj.tell() - BLOCKSIZE
#
# /usr/lib/python3.6/tarfile.py in frombuf(cls, buf, encoding, errors)
#    1028         if len(buf) == 0:
# -> 1029             raise EmptyHeaderError("empty header")
#    1030         if len(buf) != BLOCKSIZE:
#
# EmptyHeaderError: empty header
#
# ...

# %%
import transforms as T
image = Image.open(image_path_drive).convert("RGB")
image, _ = T.ToTensor()(image, None)
image    = image.to(device)

with torch.no_grad(): 
  prediction = model([image])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-a7bf8e259f31> in <module>()
#       5
#       6 with torch.no_grad():
# ----> 7   prediction = model([image])
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torchvision/models/detection/generalized_rcnn.py in forward(self, images, targets)
#      43         """
#      44         if self.training and targets is None:
# ---> 45             raise ValueError("In training mode, targets should be passed")
# ...

# %%
prediction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c3d8c93f720f> in <module>()
# ----> 1 prediction
#
# NameError: name 'prediction' is not defined

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1,prediction[0]['masks'].shape[0]+1)

axes[0].imshow(Image.fromarray(image.mul(255).permute(1, 2, 0).byte().cpu().numpy()))
for i in range(prediction[0]['masks'].shape[0]):
  axes[i+1].imshow(Image.fromarray(prediction[0]['masks'][i, 0].mul(255).byte().cpu().numpy()))

# %%
bin_treshold = 0.01
ones  = torch.ones_like(prediction[0]['masks'])
zeros = torch.zeros_like(prediction[0]['masks'])  
masks = torch.where(prediction[0]['masks'] < bin_treshold, ones, zeros)
masks

# %%
masks_names = fastrcnn_mask_functions.create_names(image_name=image_name, name='mask',
                                                   amount=prediction[0]['masks'].shape[0])
fastrcnn_mask_functions.save_here(images=masks, images_names=masks_names)
fastrcnn_mask_functions.save2drive(dir_path=masks_dir_drive, images_names=masks_names)

# %%
from google.colab import files
for mask_name in masks_names:
  print('Download {} to Local... '.format(mask_name), end=' ')
  files.download(mask_name)
  print('Done.')

# %%
masked_names = fastrcnn_mask_functions.create_names(image_name=image_name, name='masked',
                                                  amount=prediction[0]['masks'].shape[0])
fastrcnn_mask_functions.apply_mask(masks=masks, image=image, names_to_save=masked_names, device=device,
                                   to_save_in_drive=True, drive_path=masks_dir_drive)

# %%
from google.colab import files
for masked_name in masked_names:
  print('Download {} to Local... '.format(masked_name), end=' ')
  files.download(masked_name)
  print('Done.')

# %%
h_offset = 800
v_offset = 0

patched_names = fastrcnn_mask_functions.create_names(image_name=image_name, name='patched',
                                                  amount=prediction[0]['masks'].shape[0])
for i, name in enumerate(patched_names):
  mask = masks[i,:,:,:]
  fastrcnn_mask_functions.apply_patch(mask=mask, image=image, name_to_save=name, device=device,
                offset_h=h_offset, offset_v=v_offset, drive_path=masks_dir_drive)

# %%
from google.colab import files
for patched_name in patched_names:
  print('Download {} to Local... '.format(patched_name), end=' ')
  files.download(patched_name)
  print('Done.')

# %%
# os.chdir('SinGAN_Object_Completion')
# !pwd

# %%
# !git pull

# %%
# os.chdir('../')
# !pwd
