# %%
# !rm -rf SinGAN_Object_Completion

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from PIL import Image
import os

# %%
# !git clone https://github.com/manorzvi/SinGAN_Object_Completion.git
# Out:
# Cloning into 'SinGAN_Object_Completion'...
# remote: Enumerating objects: 503, done.
# remote: Counting objects: 100% (503/503), done.
# remote: Compressing objects: 100% (419/419), done.
# remote: Total 621 (delta 120), reused 453 (delta 71), pack-reused 118
# Receiving objects: 100% (621/621), 215.55 MiB | 29.51 MiB/s, done.
# Resolving deltas: 100% (125/125), done.

# %%
os.chdir('SinGAN_Object_Completion')

# %%
# !python random_samples.py --input_name 'nature7.jpg' --input_dir 'Input/People' --mode random_samples --gen_start_scale 1
# Out:
# Random Seed:  5635
# tcmalloc: large alloc 1881817088 bytes == 0xa71de000 @  0x7fe3ca1471e7 0x7fe3c7964f71 0x7fe3c79c855d 0x7fe3c79c8733 0x7fe3c7a7b8cd 0x7fe3c7a7c22e 0x7fe3c7a7eba8 0x7fe3c7bc8286 0x7fe3c7bc9da4 0x7fe3c7bcc4f2 0x7fe3c7bcd36e 0x5a522c 0x5a58f8 0x7fe3c7a86e3b 0x5a1820 0x50d76e 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50b403

# %%
from google.colab import files
import shutil

# %%
dir_to_save  = 'Output/RandomSamples/nature7/gen_start_scale=1'
print('Zip Colab workdir... ', end=' ')
shutil.make_archive(os.path.basename(dir_to_save), 'zip', dir_to_save)
print('Done.')
# Out:
# Zip Colab workdir...  Done.

# %%
dest = os.path.join('/content/gdrive/My Drive/singan', os.path.basename(dir_to_save) + '.zip')
print('Save {} to drive... '.format(os.path.basename(dir_to_save)), end=' ')
shutil.copyfile(os.path.basename(dir_to_save) + '.zip', dest)
print('Done.')
# Out:
# Save gen_start_scale=1 to drive...  Done.
