# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.chdir('/content/gdrive/My Drive/singan/SinGAN')

# %%
import torch
masks_path = '/content/gdrive/My Drive/singan/SinGAN/Input/Masks/nature3_masks'
masks_torch = torch.load(masks_path)

# %%
from PIL import Image
masks = Image.fromarray(masks_torch['masks'][0, 0].mul(255).byte().cpu().numpy())
masked_image = os.path.basename(masks_path) + '.jpg'
masks = masks.save(masked_image)

# %%
os.makedirs('TrainedModels')
os.chdir('TrainedModels')
# !cp -R ../models/nature3_model .
os.chdir('../')

# %%
# !python paint2image.py --input_name 'nature3.jpg' --input_dir 'Input/People' --ref_name masked_image --paint_start_scale 1
