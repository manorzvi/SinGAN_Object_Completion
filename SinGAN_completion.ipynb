# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
from PIL import Image
import os

# %%
# !rm -rf SinGAN_Object_Completion

# %%
# !git clone https://github.com/manorzvi/SinGAN_Object_Completion.git
# Out:
# Cloning into 'SinGAN_Object_Completion'...
# remote: Enumerating objects: 341, done.
# remote: Counting objects: 100% (341/341), done.
# remote: Compressing objects: 100% (279/279), done.
# remote: Total 459 (delta 86), reused 305 (delta 52), pack-reused 118
# Receiving objects: 100% (459/459), 200.07 MiB | 13.79 MiB/s, done.
# Resolving deltas: 100% (91/91), done.

# %%
os.chdir('SinGAN_Object_Completion')

# %%
# !python paint2image.py --input_name 'nature7.jpg' --input_dir 'Input/People' --ref_name '/content/SinGAN_Object_Completion/Input/Masks/nature7_patched_0.jpg' --paint_start_scale 1
# Out:
# Random Seed:  5385
# tcmalloc: large alloc 1881817088 bytes == 0x9282a000 @  0x7fd8e034d1e7 0x7fd8ddb6af71 0x7fd8ddbce55d 0x7fd8ddbce733 0x7fd8ddc818cd 0x7fd8ddc8222e 0x7fd8ddc84ba8 0x7fd8dddce286 0x7fd8dddcfda4 0x7fd8dddd24f2 0x7fd8dddd336e 0x5a508c 0x5a5758 0x7fd8ddc8ce3b 0x5a1670 0x50d6fe 0x509ce8 0x50aa1d 0x50c549 0x5081d5 0x50a020 0x50aa1d 0x50d320 0x509ce8 0x50aa1d 0x50c549 0x509ce8 0x50aa1d 0x50c549 0x5081d5 0x50b3a3
# no appropriate trained model is exist, please train first
# Traceback (most recent call last):
#   File "paint2image.py", line 36, in <module>
#     Gs, Zs, reals, NoiseAmp = functions.load_trained_pyramid(opt)
#   File "/content/SinGAN_Object_Completion/SinGAN/functions.py", line 253, in load_trained_pyramid
#     return Gs,Zs,reals,NoiseAmp
# UnboundLocalError: local variable 'Gs' referenced before assignment
